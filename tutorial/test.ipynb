# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use

# %%
A = use("CLARIAH/descartes-tf:clone", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/CLARIAH/descartes-tf/app</span>
# <b title="local release">data:</b> <span title="rv1.0=#422695295d3b003e61d89cfdc14b5864872ef6eb offline under /Users/me/text-fabric-data/github">~/text-fabric-data/github/CLARIAH/descartes-tf/tf/1.0</span>
# <b title="local release">data:</b> <span title="rv1.0=#422695295d3b003e61d89cfdc14b5864872ef6eb offline under /Users/me/text-fabric-data/github">~/text-fabric-data/github/CLARIAH/descartes-tf/parallels/tf/1.0</span>
# ...

# %%
query = """
sentence
  formula tex~sqrt
"""

# %%
results = A.search(query)
# Out:
#   0.00s 54 results

# %%
A.table(results, end=1, skipCols={2})
# Out:
# <table><tr class="tf ltr"><th class="tf ltr">n</th><th class="tf ltr">p</th><th class="tf ltr">sentence</th><th class="tf">formula</th></tr>
# ...

# %%
A.show(results, end=1, skipCols={2})
# Out:
# <p><b>result</b> <i>1</i>
# ...

# %%
tex = r"{\rm m} - {{\displaystyle\strut {\rm n}\over \displaystyle\strut {\rm z}}}{\rm x} + \sqrt{{\rm mm} + {\rm ox} - {{\displaystyle\strut {\rm p}\over \displaystyle\strut {\rm m}}}{\rm xx}}"
tex = f"${tex}$"

# %%
tex
# Out:
# '${\\rm m} - {{\\displaystyle\\strut {\\rm n}\\over \\displaystyle\\strut {\\rm z}}}{\\rm x} + \\sqrt{{\\rm mm} + {\\rm ox} - {{\\displaystyle\\strut {\\rm p}\\over \\displaystyle\\strut {\\rm m}}}{\\rm xx}}$'

# %%
print(tex)
# Out:
# ${\rm m} - {{\displaystyle\strut {\rm n}\over \displaystyle\strut {\rm z}}}{\rm x} + \sqrt{{\rm mm} + {\rm ox} - {{\displaystyle\strut {\rm p}\over \displaystyle\strut {\rm m}}}{\rm xx}}$

# %%
A.dh(f"""
<span style="display: inline-block; max-width: 100%; width: min-content;">
<span>a</span>
<div>{tex}</div>
<span>b</span>
</span>
""")
# Out:
# <span style="display: inline-block; max-width: 100%; width: min-content;">
# <span>a</span>
# <div>${\rm m} - {{\displaystyle\strut {\rm n}\over \displaystyle\strut {\rm z}}}{\rm x} + \sqrt{{\rm mm} + {\rm ox} - {{\displaystyle\strut {\rm p}\over \displaystyle\strut {\rm m}}}{\rm xx}}$</div>
# <span>b</span>
# </span>
